# %%
from detoxify import Detoxify
import pandas as pd
from tqdm import tqdm

# %%
df1 = pd.read_csv('/Users/hgardner/Desktop/toxicity/tox_t.csv')
df2 = pd.read_csv('/Users/hgardner/Desktop/toxicity/data/preprocessed_data/cat_title.csv')

# %%
df = df1.merge(df2, on='bibid', how='left')

# %%
df = df.drop(['title_y','Unnamed: 0'], axis=1)

# %%
model = Detoxify('multilingual',device='cpu')
tqdm.pandas()

# %%
df['identity_attack'] = df['clean_title'].progress_map(lambda line: model.predict(line)['identity_attack'])
# Out:
#   1%|▏         | 421/29058 [00:57<1:05:43,  7.26it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W3sdW50aXRsZWQ%3D?line=0'>1</a> df['identity_attack'] = df['clean_title'].progress_map(lambda line: model.predict(line)['identity_attack'])
#
# File /opt/anaconda3/lib/python3.9/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4237, in Series.map(self, arg, na_action)
# ...
